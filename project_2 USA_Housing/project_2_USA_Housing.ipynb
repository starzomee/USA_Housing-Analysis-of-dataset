# %% [markdown]
# # objective 1

# %% [markdown]
# # data

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import sklearn 
import seaborn as sns 
import warnings 
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize'] = [10 , 5]

# impprt warnings 
import warnings 
warnings.simplefilter(action = 'ignore' , category = FutureWarning)

# %%
 full_data = pd.read_csv('USA_Housing.csv')
full_data
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
print('full data :' , full_data.shape)
# Out:
# full data : (5000, 7)

# %%
full_data.head(5)
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
sns.heatmap(full_data.isnull(), yticklabels = False , cbar = False , cmap = 'tab20c_r')
plt.title("Missing Data : training Set")
plt.show()

# %%
# remove address 
full_data.drop('Address' , axis = 1 , inplace = True )

# %%
# remove missing values form the dataset 
full_data.dropna(inplace = True)

# %%
full_data
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price
# ...

# %%
full_data.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %% [markdown]
# # getting ready with the model

# %%
full_data.shape
# Out:
# (5000, 6)

# %% [markdown]
# # machine learning

# %%
# split data to be used by the model 
# Create matrix of features 
x = full_data.drop('Price' , axis = 1)   # grabe all else but 'Price'

# Create target variable 
y = full_data['Price']  # y is the column to be predicted

# %%
x.shape
# Out:
# (5000, 5)

# %%
y.shape
# Out:
# (5000,)

# %%
# Use x and y variable to split the training and testing data into train and test set 
from sklearn.model_selection import train_test_split 
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size = .20 , random_state = 101)

# %%
x_train.shape
x_train
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 3413      69048.788093             6.619712                   6.123813
# 1610      67866.899929             5.393978                   9.359022
# 3459      56636.238191             5.497667                   7.121872
# 4293      79310.361977             4.247434                   7.518204
# 1039      72821.247664             6.480819                   7.116655
# ...                ...                  ...                        ...
# 4171      56610.642563             4.846832                   7.558137
# 599       70596.850945             6.548274                   6.539986
# 1361      55621.899104             3.735942                   6.868291
# 1547      63044.460096             5.935261                   5.913454
# 4959      75078.791516             7.644779                   8.440726
#
#       Avg. Area Number of Bedrooms  Area Population
# 3413                          4.33     36817.368760
# ...

# %%
y_train
# Out:
# 3413    1.305210e+06
# 1610    1.400961e+06
# 3459    1.048640e+06
# 4293    1.231157e+06
# 1039    1.391233e+06
#             ...
# 4171    7.296417e+05
# 599     1.599479e+06
# 1361    1.102641e+06
# 1547    8.650995e+05
# 4959    2.108376e+06
# Name: Price, Length: 4000, dtype: float64

# %%
x_test.shape
x_test
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 1718      66774.995817             5.717143                   7.795215
# 2511      62184.539375             4.925758                   7.427689
# 345       73643.057298             6.766853                   8.337085
# 2521      61909.041438             6.228343                   6.593138
# 54        72942.705059             4.786222                   7.319886
# ...                ...                  ...                        ...
# 3900      77615.851343             6.200603                   6.909327
# 3753      66925.199349             5.153050                   8.396903
# 3582      71778.026176             5.921280                   7.411045
# 2392      87272.093393             5.025866                   7.184765
# 3343      70271.104195             5.856327                   6.782116
#
#       Avg. Area Number of Bedrooms  Area Population
# 1718                          4.32     36788.980327
# ...

# %%
y_test
# Out:
# 1718    1.251689e+06
# 2511    8.730483e+05
# 345     1.696978e+06
# 2521    1.063964e+06
# 54      9.487883e+05
#             ...
# 3900    1.466412e+06
# 3753    1.222412e+06
# 3582    1.404622e+06
# 2392    9.100996e+05
# 3343    1.188197e+06
# Name: Price, Length: 1000, dtype: float64

# %% [markdown]
# # linear Regression

# %% [markdown]
# # model Training

# %%
# fit 
# import model 
from sklearn.linear_model import LinearRegression 

# Create instance of model 
lin_reg = LinearRegression()

# Pass training data into the model 
lin_reg.fit(x_train , y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # model testing

# %% [markdown]
# # Class prediction

# %%
# prediction 
y_pred = lin_reg.predict(x_test)
print(y_pred.shape)
print(y_pred)
# Out:
# (1000,)
# [1257919.729097    822112.41884197 1740669.05865495  972452.12917494
#   993422.26329315  644126.07414456 1073911.79101682  856584.00194133
#  1445318.25518365 1204342.19071174 1455792.46212863 1298556.65696433
#  1735924.33836095 1336925.77577789 1387637.43231922 1222403.77772069
#   613786.28691982  963933.54416267 1221197.33050139 1198071.57563599
#   505861.89531673 1769106.54723353 1853881.16842511 1200369.50507868
#  1065129.1285072  1812033.73067312 1768686.47091262 1439920.83814323
#  1387251.99649376 1541178.39224181  726418.80504278 1754497.60908688
#  1462185.72653198 1025600.16081144 1284926.8685155   917454.59590853
#  1187046.94956865  999330.91117487 1329536.63409595  782191.60441437
#  1393272.03053841  578216.88394851  822643.37151048 1895533.11413226
#  1672019.84892041  966926.45434583 1129674.55638146  792797.75914663
#  1161057.18412143 1472396.71417164 1457656.70412313 1162939.334229
# ...

# %%
sns.scatterplot(x =y_test , y = y_pred , color = "blue" , label = "Actual Data Points ")
plt.plot([min(y_test) , max(y_test)] , [min(y_test) , max(y_test)] , color = "red"  , label = "Ideal line")
plt.legend()
plt.show()

# %%
# combine actual and predicted values side by side 
results = np.column_stack((y_test , y_pred))

# %%
# printing the results 
print("Actual values   |  Predicted values")
print('----' * 30)
for actual , predicted in results:
    print(f"{actual:14.2f}   | {predicted:12.2f}")
# Out:
# Actual values   |  Predicted values
# ------------------------------------------------------------------------------------------------------------------------
#     1251688.62   |   1257919.73
#      873048.32   |    822112.42
#     1696977.66   |   1740669.06
#     1063964.29   |    972452.13
#      948788.28   |    993422.26
#      730043.65   |    644126.07
#     1166925.15   |   1073911.79
#      705444.12   |    856584.00
#     1499988.88   |   1445318.26
#     1288199.15   |   1204342.19
#     1441736.76   |   1455792.46
#     1279681.15   |   1298556.66
#     1754969.16   |   1735924.34
#     1511653.45   |   1336925.78
#     1441956.20   |   1387637.43
#     1119992.62   |   1222403.78
#      727866.53   |    613786.29
#     1138885.10   |    963933.54
#     1074263.32   |   1221197.33
#     1386473.37   |   1198071.58
#      404643.60   |    505861.90
#     1449829.49   |   1769106.55
#     1775874.76   |   1853881.17
#     1202050.58   |   1200369.51
# ...

# %% [markdown]
# # Residual Anaylsis

# %%
residual = actual - y_pred.reshape(-1)
print(residual)
# Out:
# [-6.97228472e+04  3.66084463e+05 -5.52472177e+05  2.15744753e+05
#   1.94774619e+05  5.44070808e+05  1.14285091e+05  3.31612880e+05
#  -2.57121373e+05 -1.61453088e+04 -2.67595580e+05 -1.10359775e+05
#  -5.47727456e+05 -1.48728894e+05 -1.99440550e+05 -3.42068958e+04
#   5.74410595e+05  2.24263338e+05 -3.30004486e+04 -9.87469372e+03
#   6.82334987e+05 -5.80909665e+05 -6.65684287e+05 -1.21726232e+04
#   1.23067753e+05 -6.23836849e+05 -5.80489589e+05 -2.51723956e+05
#  -1.99055115e+05 -3.52981510e+05  4.61778077e+05 -5.66300727e+05
#  -2.73988845e+05  1.62596721e+05 -9.67299866e+04  2.70742286e+05
#   1.14993234e+03  1.88865971e+05 -1.41339752e+05  4.06005277e+05
#  -2.05075149e+05  6.09979998e+05  3.65553510e+05 -7.07336232e+05
#  -4.83822967e+05  2.21270428e+05  5.85223255e+04  3.95399123e+05
#   2.71396978e+04 -2.84199832e+05 -2.69459822e+05  2.52575477e+04
#   8.87432008e+04 -1.69910564e+05  3.47093178e+05  2.01874576e+05
# ...

# %%
# distribution plot for the residual analysis (difference between actaul and predicted )
sns.displot(residual , kde = True)
plt.show()

# %% [markdown]
# # Model Evaluation

# %%
# Score it 
from sklearn.metrics import mean_squared_error 

print("Linear Regression Model ")
# results 
print("--"*30)
# mean_squared_error(y_test, y_pred)
mse = mean_squared_error(y_test , y_pred)
rmse = np.sqrt(mse)

# print evaluation matrics 
print("Mean Squared Error" , mse)
 
print("Root Mean Squared Error" , rmse)
# Out:
# Linear Regression Model
# ------------------------------------------------------------
# Mean Squared Error 10100187858.864885
# Root Mean Squared Error 100499.69083964829

# %% [markdown]
# # objective 2

# %%
from sklearn import preprocessing 
pre_process = preprocessing.StandardScaler().fit(x)
x_transform = pre_process.fit_transform(x)

# %%
print(x_transform.shape)
x_transform
# Out:
# (5000, 5)
# array([[ 1.02865969, -0.29692705,  0.02127433,  0.08806222, -1.31759867],
#        [ 1.00080775,  0.02590164, -0.25550611, -0.72230146,  0.40399945],
#        [-0.68462916, -0.11230283,  1.5162435 ,  0.93084045,  0.07240989],
#        ...,
#        [-0.48723454,  1.28447022, -2.17026949, -1.50025059, -0.29193658],
#        [-0.05459152, -0.44669439,  0.14154061,  1.18205319,  0.65111608],
#        [-0.28831272,  0.01521477, -0.19434166,  0.07185495,  1.04162464]])

# %%
y.shape
# Out:
# (5000,)

# %%
# use x and y variables to split training and testing data into test and train set 
from sklearn.model_selection import train_test_split
x_train , x_test , y_train  , y_test = train_test_split(x_transform, y , test_size = .10 ,
random_state = 101)

# %% [markdown]
# # LINEAR REGRESSION

# %% [markdown]
# # Model Training

# %%
# fit 
# import model 
from sklearn.linear_model import LinearRegression 
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 


# Create instance of model 
lin_reg = LinearRegression()

# pass training data into the model 
lin_reg.fit(x_train , y_train)




# pipe = make_pipe(StandardScaler() , LinearRegression())
# pipe.fit(x_train , y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # model tranining

# %% [markdown]
# # class prediction

# %%
y_pred = lin_reg.predict(x_test)
print(y_pred.shape)
print(y_pred)
# Out:
# (500,)
# [1257098.09685349  822086.76211938 1739484.60206384  973128.9269703
#   993918.45735573  645734.60078802 1074412.81648685  856463.98369062
#  1445048.63352694 1201847.71924782 1454475.51805014 1296582.98910134
#  1736858.04511704 1336694.59015483 1386280.00636484 1223122.34992068
#   615840.7860361   964515.62334817 1222020.63802963 1197532.31828304
#   506756.96702134 1767894.37065039 1854829.42630351 1198521.37525139
#  1065384.60130188 1810199.62960618 1767830.26189968 1440162.9747667
#  1386122.51652193 1539972.94909227  729561.93190619 1754434.69364763
#  1465273.07428251 1026021.79840116 1283514.57970667  917688.32850804
#  1185681.03610736 1000137.89595728 1329344.79847155  784262.29954368
#  1392528.47637802  576569.30274928  823465.14446257 1893895.24014477
#  1671565.73974773  964720.06183539 1129280.90868273  792574.96874635
#  1159381.43948676 1473209.24685792 1459527.31772498 1164492.85979007
# ...

# %%
sns.scatterplot(x=y_test , y = y_pred , color = "blue" , label = "Actual Data Points")
plt.plot([min(y_test) , max(y_test)] , [min(y_test) , max(y_test)] , color = "red" , label  = "Ideal Line" 
        )
plt.legend()
plt.show()

# %%
# printing the results 
print("Actual Values   |  Predicted Values")
print("--"*30)
for actual , predicted in results:
    print(f"{actual : 14.2f} | {predicted : 12.2f}")
# Out:
# Actual Values   |  Predicted Values
# ------------------------------------------------------------
#     1251688.62 |   1257919.73
#      873048.32 |    822112.42
#     1696977.66 |   1740669.06
#     1063964.29 |    972452.13
#      948788.28 |    993422.26
#      730043.65 |    644126.07
#     1166925.15 |   1073911.79
#      705444.12 |    856584.00
#     1499988.88 |   1445318.26
#     1288199.15 |   1204342.19
#     1441736.76 |   1455792.46
#     1279681.15 |   1298556.66
#     1754969.16 |   1735924.34
#     1511653.45 |   1336925.78
#     1441956.20 |   1387637.43
#     1119992.62 |   1222403.78
#      727866.53 |    613786.29
#     1138885.10 |    963933.54
#     1074263.32 |   1221197.33
#     1386473.37 |   1198071.58
#      404643.60 |    505861.90
#     1449829.49 |   1769106.55
#     1775874.76 |   1853881.17
#     1202050.58 |   1200369.51
#     1105737.46 |   1065129.13
#     1835564.69 |   1812033.73
#     1795428.77 |   1768686.47
#     1424283.37 |   1439920.84
# ...

# %% [markdown]
# # RESIDUAL ANALYSIS
#                             # actual - predicted

# %%
residual = actual - y_pred.reshape(-1)
print(residual)
# Out:
# [  -68901.21494221   366110.1197919   -551287.72015256   215067.95494099
#    194278.42455555   542462.28112326   113784.06542444   331732.89822067
#   -256851.75161566   -13650.83733654  -266278.63613885  -108386.10719006
#   -548661.16320575  -148497.70824355  -198083.12445356   -34925.4680094
#    572356.09587518   223681.25856311   -33823.75611835    -9335.43637175
#    681439.91488995  -579697.48873911  -666632.54439223   -10324.49334011
#    122812.28060941  -622002.7476949   -579633.3799884   -251966.09285541
#   -197925.63461065  -351776.06718098   458634.9500051   -566237.81173635
#   -277076.19237123   162175.08351012   -95317.69779539   270508.55340324
#      2515.84580392   188058.985954    -141147.91656026   403934.5823676
#   -204331.59446674   611627.57916201   364731.73744871  -705698.35823349
#   -483368.85783645   223476.82007589    58915.97322855   395621.91316493
#     28815.44242452  -285012.36494664  -271330.43581369    23704.02212121
# ...

# %%
# distribution plot 
sns.displot(residual , kde = True)
plt.show()

# %% [markdown]
# # Model Evaluation
#                    # Linear Regression

# %%
# Score 
from sklearn.metrics import mean_squared_error

print("Linear   Regression  Model ")
print("--"*20) 
# mean_squared_error(y_test , y_pred) 
mse = mean_squared_error(y_test , y_pred)
rmse = np.sqrt(mse)

# print evaluatin metrics 
print("mean_squared_error :" , mse)
print("root_mean_squared_error :" , rmse)
# Out:
# Linear   Regression  Model
# ----------------------------------------
# mean_squared_error : 9839952411.80171
# root_mean_squared_error : 99196.53427313734

# %% [markdown]
# # objective 3

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

rf_regressor = DecisionTreeRegressor()
rf_regressor.fit(x_train , y_train)

# predicting the SalePrice using test set
y_pred_rf = rf_regressor.predict(x_test)

Dtr = mean_squared_error(y_pred_rf , y_test)

print("Decision Tree Regressor :" ,  Dtr)
# Out:
# Decision Tree Regressor : 30984377014.687088

# %% [markdown]
# # Random forest

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

rf_regressor = RandomForestRegressor()
rf_regressor.fit(x_train , y_train)

# predicting the SalePrice using test set
y_pred_rf = rf_regressor.predict(x_test)

RFr = mean_squared_error(y_pred_rf , y_test)

print("Random Forest Regressor :" ,  RFr)
# Out:
# Random Forest Regressor : 14388302870.280298

# %% [markdown]
# # Gradient Boosting Regression

# %%
from sklearn.tree import DecisionTreeRegressor 
from sklearn.ensemble import RandomForestRegressor 
from sklearn.ensemble import GradientBoostingRegressor 

rf_regressor  = GradientBoostingRegressor()
rf_regressor.fit(x_train , y_train)

# predict 
y_pred_rf = rf_regressor.predict(x_test)
# random forest regressor accuracy check test 
GBr = mean_squared_error(y_pred_rf , y_test)
print("Gradient Boosting Regresstion :" , GBr)
# Out:
# Gradient Boosting Regresstion : 12062123606.35595

# %% [markdown]
# # sample model scores
#               # replace these with your actual model scores

# %%
# sample model scores (replace these with your actual model scores)
model_scores = {
    "Linear Regression" : 9839952411.80171 , 
    "Decision Tree    " : 31049354575.52404 , 
    "Random Forest "    : 14152882586.058907 , 
    "Gradient Bossting ":  12052645414.935028
}

# sort the model scores in ascending order based on their values (lower values first) 
sorted_scores = sorted(model_scores.items() , key = lambda x: x[1])

# display the ranking of the model  
print("Model Ranking (lower values are better :)")
for rank , (model_name , score ) in enumerate(sorted_scores , start = 1):
    print(f"{rank} ->  {model_name}:  {score}")
# Out:
# Model Ranking (lower values are better :)
# 1 ->  Linear Regression:  9839952411.80171
# 2 ->  Gradient Bossting :  12052645414.935028
# 3 ->  Random Forest :  14152882586.058907
# 4 ->  Decision Tree    :  31049354575.52404
